# %%
import pandas as pd
from pandas import read_csv
import pandas as pd
import matplotlib.pyplot as plt
import math
  
import matplotlib.pyplot as plt
import numpy as np
import scipy
  
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

import seaborn as sns

df = read_csv('puretone_all.csv')

# %%
regression_model = LinearRegression()
m, b = np.polyfit(df.Distance, df.Gmean, 1)

# %%
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(df.Distance, df.Gmean)

# %%
slope
# Out:
# 0.7848373312053107

# %%
p_value
# Out:
# 4.0017268728829546e-14

# %%
r_value, r_value**2
# Out:
# (0.9923575300980007, 0.9847734675422043)

# %%
std_err, intercept
# Out:
# (0.026082425241605076, 0.7559164068366364)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax2 = ax1.twiny()

plt.grid()
ax1.plot(df.Distance, df.Gmean, 'x')
ax1.set_xlabel(r"Actual Positions on Slider")
ax1.set_ylabel(r"Geometric Means of Estimated Position")
ax1.plot(df.Distance, m*df.Distance + b, label = 'Estimated')
ax1.plot(df.Distance, df.Distance, label = 'Ideal')

ax1.legend()

ax2.plot(df.bpm, df.Gmean, 'x')

ax2.set_xlabel(r"BPM (Beats per Minute)")
plt.text(10,12, 'm=0.78', fontsize=10)
plt.text (10,11,'std_err=0.026, $r^2$=0.985',fontsize=10)
plt.title("Pure Tone Beating Condition",color = 'blue')
plt.savefig("pure_tone_graph.png", dpi=400, bbox_inches='tight')
plt.show()
